# %%
import pandas as pd

file_path = "nishant tyagi project 3.xlsx"

df = pd.read_excel(file_path)

print(df.head())
print(df.columns)
# Out:
#   Month  Department  Budgeted Amount  Actual Spending  Variance
# 0   Dec     Finance             9701             9203      -498
# 1   Jul          HR             8726             5921     -2805
# 2   Jun       Sales            19127            20448      1321
# 3   Feb       Sales            13403            14716      1313
# 4   Aug  Operations            14801            16427      1626
# Index(['Month', 'Department', 'Budgeted Amount', 'Actual Spending',
#        'Variance'],
#       dtype='object')

# %%
df = df.dropna()
df.columns = df.columns.str.strip()
print(df.head())
# Out:
#   Month  Department  Budgeted Amount  Actual Spending  Variance
# 0   Dec     Finance             9701             9203      -498
# 1   Jul          HR             8726             5921     -2805
# 2   Jun       Sales            19127            20448      1321
# 3   Feb       Sales            13403            14716      1313
# 4   Aug  Operations            14801            16427      1626

# %%
df.to_csv("finance_clean.csv", index=False)
